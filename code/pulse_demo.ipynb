# %%
import ee
import numpy as np
import pandas as pd
import geopandas as gp
from tqdm import tqdm

import matplotlib.pyplot as plt

ee.Initialize()

# %%
# Set up the data objects to query EE
data = {}

# Image collection, variable name, scaling factor, spatial res
#data['prism'] = [ee.ImageCollection("OREGONSTATE/PRISM/AN81m"), "ppt", 1, 4000]
#data['persiann'] = [ee.ImageCollection("NOAA/PERSIANN-CDR"), "precipitation", 1, 25000]
data['gpm'] = [ee.ImageCollection("NASA/GPM_L3/IMERG_MONTHLY_V06"), "precipitation", 720, 12500] # 
data['lst'] = [ee.ImageCollection("ECMWF/ERA5_LAND/MONTHLY"), "skin_temperature", 1, 11132]
print(data['lst'])
# Out:
# [<ee.imagecollection.ImageCollection object at 0x7fd1f00b8f28>, 'skin_temperature', 1, 11132]

# %%
gdf = gp.read_file("../shape/cv.shp")
gdf.plot()

# %%
# Functions 

# Convert gdf to earth engine object 
def gdf_to_ee_poly(gdf, simplify = True):

    if simplify:
        gdf = gdf.geometry.simplify(0.01)
    
    lls = gdf.geometry.iloc[0]
    x,y = lls.exterior.coords.xy
    coords = [list(zip(x,y))]
    area = ee.Geometry.Polygon(coords)

    return area

def get_ims(dataset, startdate,enddate, area, return_dates = False, table = False, monthly_mean = False,  monthly_sum = False):
    
    '''
    Returns gridded images for EE datasets 
    '''

    ImageCollection = dataset[0]
    var = dataset[1]
    scaling_factor = dataset[2]
    native_res = dataset[3]

    dt_idx = pd.date_range(startdate,enddate, freq='MS')
    ims = []
    seq = ee.List.sequence(0, len(dt_idx)-1)
    num_steps = seq.getInfo()

    print("processing:")
    print("{}".format(ImageCollection.first().getInfo()['id']))

    for i in tqdm(num_steps):

        start = ee.Date(startdate).advance(i, 'month')
        end = start.advance(1, 'month');

        im = ee.ImageCollection(ImageCollection).select(var).filterDate(start, end).set('system:time_start', end.millis())
        result = im.getRegion(area,native_res,"epsg:4326").getInfo()
        ims.append(result)

    results = []
    dates = []

    print("postprocesing")

    for im in tqdm(ims):
        header, data = im[0], im[1:]

        df = pd.DataFrame(np.column_stack(data).T, columns = header)
        df.latitude = pd.to_numeric(df.latitude)
        df.longitude = pd.to_numeric(df.longitude)
        df[var] = pd.to_numeric(df[var])

        images = []

        for idx,i in enumerate(df.id.unique()):

            t1 = df[df.id==i]
            arr = array_from_df(t1,var)
            arr[arr == 0] = np.nan
            images.append(arr*scaling_factor)# This is the only good place to apply the scaling factor. 

            if return_dates:
                date = df.time.iloc[idx]
                dates.append(datetime.datetime.fromtimestamp(date/1000.0))

        results.append(images) 

    print("====COMPLETE=====")

    return [item for sublist in results for item in sublist] 
    
def array_from_df(df, variable):    

    '''
    Convets a pandas df with lat, lon, variable to a numpy array 
    '''

    # get data from df as arrays
    lons = np.array(df.longitude)
    lats = np.array(df.latitude)
    data = np.array(df[variable]) # Set var here 
                                              
    # get the unique coordinates
    uniqueLats = np.unique(lats)
    uniqueLons = np.unique(lons)

    # get number of columns and rows from coordinates
    ncols = len(uniqueLons)    
    nrows = len(uniqueLats)

    # determine pixelsizes
    ys = uniqueLats[1] - uniqueLats[0] 
    xs = uniqueLons[1] - uniqueLons[0]

    # create an array with dimensions of image
    arr = np.zeros([nrows, ncols], np.float32)

    # fill the array with values
    counter =0
    for y in range(0,len(arr),1):
        for x in range(0,len(arr[0]),1):
            if lats[counter] == uniqueLats[y] and lons[counter] == uniqueLons[x] and counter < len(lats)-1:
                counter+=1
                arr[len(uniqueLats)-1-y,x] = data[counter] # we start from lower left corner
    
    return arr

def write_raster(array,gdf,outfn):
    '''
    converts a numpy array and a geopandas gdf to a geotiff
    Data values are stored in np.array
    spatial coordinates stored in gdf
    outfn - outpath
    '''
    
    xmin, ymin = gdf.bounds.minx.values[0], gdf.bounds.miny.values[0]
    xmax, ymax = gdf.bounds.maxx.values[0], gdf.bounds.maxy.values[0]
    nrows, ncols = array.shape
    xres = (xmax-xmin)/float(ncols)
    yres = (ymax-ymin)/float(nrows)
    geotransform =(xmin,xres,0,ymax,0, -yres)   

    output_raster = gdal.GetDriverByName('GTiff').Create(outfn,ncols, nrows, 1 , gdal.GDT_Float32)  # Open the file
    output_raster.SetGeoTransform(geotransform)  # Specify coords
    srs = osr.SpatialReference()                 # Establish encoding
    srs.ImportFromEPSG(4326)                     # WGS84 lat long
    output_raster.SetProjection(srs.ExportToWkt() )   # Export coordinate system 
    output_raster.GetRasterBand(1).WriteArray(array)   # Write array to raster
    
    print("wrote {}".format(outfn))
    return outfn

# %%
# Convert gdf to ee object
area = gdf_to_ee_poly(gdf)

# specify start / end 
startdate = '2001-09-30'
enddate = '2021-09-30'

#gpm = get_ims(data['gpm'], startdate, enddate, area)
temp = get_ims(data['lst'], startdate, enddate, area)
# Out:
# processing:
# ECMWF/ERA5_LAND/MONTHLY/198101
# 100%|██████████| 240/240 [02:03<00:00,  1.94it/s]
# postprocesing
# 100%|██████████| 240/240 [00:01<00:00, 133.59it/s]
# ====COMPLETE=====

# %%
# stack the ims and calc mean
annual_mean = np.nanmean(np.dstack(gpm), axis = 2)
timeseries = np.array([np.nanmean(x) for x in gpm])

print(temp)
annual_mean_temp = np.nanmean(np.dstack(temp), axis = 2)
timeseries_temp = np.array([np.nanmean(x) for x in temp])
# Out:
# [array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 291.37347, ...,       nan,       nan,
#               nan],
#        [      nan, 292.2016 , 291.46527, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 296.9184 ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 293.23676, 296.18207,
#               nan],
#        [      nan,       nan,       nan, ..., 294.33832,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 282.12805, ...,       nan,       nan,
#               nan],
#        [      nan, 283.07727, 282.44836, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 286.78625,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 284.47375, 286.1593 ,
#               nan],
#        [      nan,       nan,       nan, ..., 285.17493,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 278.56982, ...,       nan,       nan,
#               nan],
#        [      nan, 279.45264, 278.8706 , ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 281.2788 ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 278.32178, 280.60303,
#               nan],
#        [      nan,       nan,       nan, ..., 279.71826,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 276.8169 , ...,       nan,       nan,
#               nan],
#        [      nan, 278.229  , 277.1001 , ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 280.56494,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 278.34424, 280.18994,
#               nan],
#        [      nan,       nan,       nan, ..., 279.2583 ,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 280.03558, ...,       nan,       nan,
#               nan],
#        [      nan, 281.31097, 280.21136, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 284.5395 ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 281.49847, 283.8891 ,
#               nan],
#        [      nan,       nan,       nan, ..., 282.72113,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 281.756  , ...,       nan,       nan,
#               nan],
#        [      nan, 282.6564 , 281.88687, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 288.97867,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 284
,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 278.57684, ...,       nan,       nan,
#               nan],
#        [      nan, 279.81512, 278.9323 , ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 282.58856,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 280.68622, 282.1081 ,
#               nan],
#        [      nan,       nan,       nan, ..., 281.24286,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 279.85757, ...,       nan,       nan,
#               nan],
#        [      nan, 281.26578, 280.1193 , ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 285.12125,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 282.1525 , 284.4103 ,
#               nan],
#        [      nan,       nan,       nan, ..., 283.11343,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 281.53223, ...,       nan,       nan,
#               nan],
#        [      nan, 282.40723, 281.67285, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 288.8213 ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 284.97754, 288.04785,
#               nan],
#        [      nan,       nan,       nan, ..., 286.20605,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 288.63306, ...,       nan,       nan,
#               nan],
#        [      nan, 289.23853, 288.54907, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 297.39673,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 293.70337, 296.65454,
#               nan],
#        [      nan,       nan,       nan, ..., 294.14282,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 295.20685, ...,       nan,       nan,
#               nan],
#        [      nan, 295.44513, 295.22052, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 302.94513,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 299.28107, 302.2381 ,
#               nan],
#        [      nan,       nan,       nan, ..., 299.35333,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 301.87787, ...,       nan,       nan,
#               nan],
#        [      nan, 301.65717, 301.84857, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 308.1513 ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 305.13763, 307.72357,
#               nan],
#        [      nan,       nan,       nan, ..., 305.04974,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 305.63666, ...,       nan,       nan,
#               nan],
#        [      nan, 305.04095, 305.57806, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 311.66986,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 308.46478, 311.0312 ,
#               nan],
#        [      nan,       nan,       nan, ..., 308.3769 ,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 303.51416, ...,       nan,       nan,
#               nan],
#        [      nan, 302.9497 , 303.40283, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 309.354  ,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 305.83252, 308.60596,
#               nan],
#        [      nan,       nan,       nan, ..., 305.938  ,       nan,
#               nan]], dtype=float32), array([[      nan,       nan,       nan, ...,       nan,       nan,
#               nan],
#        [      nan,       nan, 297.58475, ...,       nan,       nan,
#               nan],
#        [      nan, 297.78787, 297.62576, ...,       nan,       nan,
#               nan],
#        ...,
#        [      nan,       nan,       nan, ..., 304.70975,       nan,
#               nan],
#        [      nan,       nan,       nan, ..., 301.37576, 303.8074 ,
#               nan],
#        [      nan,       nan,       nan, ..., 301.39334,       nan,
#               nan]], dtype=float32)]
# /Users/mmorphew/opt/anaconda3/envs/elev/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: Mean of empty slice
#
# /Users/mmorphew/opt/anaconda3/envs/elev/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: Mean of empty slice

# %%
# plot
plt.imshow(temp[1])
plt.colorbar()
plt.axis('off')
plt.show()

# %%
dates = pd.date_range(startdate,enddate, freq = "M")
plt.plot(dates, timeseries)
# Out:
# --------------------------------------------------------------------------
# ValueError                               Traceback (most recent call last)
# <ipython-input-68-493ee3979dc0> in <module>
#       1 dates = pd.date_range(startdate,enddate, freq = "M")
# ----> 2 plt.plot(dates, timeseries)
#
# ~/opt/anaconda3/envs/elev/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2794     return gca().plot(
#    2795         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2796         is not None else {}), **kwargs)
#    2797
#    2798
#
# ~/opt/anaconda3/envs/elev/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~/opt/anaconda3/envs/elev/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~/opt/anaconda3/envs/elev/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# ~/opt/anaconda3/envs/elev/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (241,) and (235,)

# %%
# write 
rs.write_raster(annual_mean,gdf,"../prism.tif")

# %%
im = ee.ImageCollection(ImageCollection).select(var).filterDate(start, end).set('system:time_start', end.millis())
# Out:
# --------------------------------------------------------------------
# NameError                          Traceback (most recent call last)
# <ipython-input-69-26d61af29a2a> in <module>
# ----> 1 im = ee.ImageCollection(ImageCollection).select(var).filterDate(start, end).set('system:time_start', end.millis())
#
# NameError: name 'ImageCollection' is not defined
